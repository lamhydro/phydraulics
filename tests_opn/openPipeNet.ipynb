# %% [markdown]
# # Redes de tuberias abiertas
# ## Comprobación de diseño
# ### **Ejemplo No.1**
# > En la siguiente figura se muestra el esquema de una red abierta que forma parte del sistema de abastecimiento de agua de una poblacion. Calcular los caudales que llegan a los embalses B,C,D y E. Todas las tuberias son de asbesto cemento con una rugosidad $\varepsilon = 0.03$ $mm$. Es posible suponer que no existen perdidas menores.
#
# > - $\rho =$ 999.1 kg/m$^3$
# > - $\nu =$ 1.14x10$^{-6}$ m$^2$/s
#
# ![alternatvie text](./figs/fjs65.jpeg)
#
# > *Solucion:*

# %% [markdown]
# > Siguiendo el procedimiento descrito, se tiene:

# %% [markdown]
# > La imformacion de entrada al programa es:

# %%
import json
with open('designTest_js61.json', 'r') as f:
    data = json.load(f)
data
# Out:
# {'PT': 1,
#  'US': 'IS',
#  'IM': 'nr',
#  'rho': 999.1,
#  'mu': '',
#  'nu': 1.14e-06,
#  'RE1': {'z': 43},
#  'RE2': {'z': 34},
#  'RE3': {'z': 30},
#  'RE4': {'z': 12},
#  'RE5': {'z': 0},
#  'N1': {'z': 37.0, 'Q': 0.12},
#  'N2': {'z': 15.0, 'Q': 0.1},
#  'P1': {'S': 'RE1',
#   'E': 'N1',
#   'Q': '',
#   'Pu': {'P': '', 'h': '', 'ef': 1},
#   'D': 0.4572,
#   'L': 800,
#   'ks': 3e-05,
#   'K': [0]},
#  'P2': {'S': 'N1',
#   'E': 'RE2',
#   'Q': '',
#   'Pu': {'P': '', 'h': '', 'ef': 1},
#   'D': 0.1524,
#   'L': 600,
#   'ks': 3e-05,
#   'K': [0]},
#  'P3': {'S': 'N1',
#   'E': 'RE3',
#   'Q': '',
#   'Pu': {'P': '', 'h': '', 'ef': 1},
#   'D': 0.1524,
#   'L': 700,
#   'ks': 3e-05,
#   'K': [0]},
#  'P4': {'S': 'N1',
#   'E': 'N2',
#   'Q': '',
#   'Pu': {'P': '', 'h': '', 'ef': 1},
#   'D': 0.3048,
#   'L': 550,
#   'ks': 3e-05,
#   'K': [0]},
#  'P5': {'S': 'N2',
#   'E': 'RE4',
#   'Q': '',
#   'Pu': {'P': '', 'h': '', 'ef': 1},
#   'D': 0.1524,
#   'L': 300,
# ...

# %%
# %run main.py designTest_js61.json
# Out:
# Proving the design of a open pipe network
#
#
# ITERATION No.: 1
#
# ---> Resulst for Node: N1
#           Q              H               V                   f
#          In       Out   In   Out        In       Out        In       Out
# P1  0.37287       NaN  6.0   NaN  2.271201       NaN  0.013042       NaN
# P2      NaN  0.016436  NaN   3.0       NaN  0.901031       NaN  0.018415
# P3      NaN  0.023916  NaN   7.0       NaN  1.311093       NaN  0.017395
# P4      NaN  0.309702  NaN  22.0       NaN  4.244475       NaN  0.013278
# ---> Resulst for Node: N2
#            Q                    H               V                  f
#           In       Out         In   Out        In       Out       In       Out
# P4  0.292504       NaN  19.716484   NaN  4.008778       NaN  0.01334       NaN
# P5       NaN  0.023916        NaN   3.0       NaN  1.311093      NaN  0.017395
# P6       NaN  0.069664        NaN  15.0       NaN  3.818970      NaN  0.015376
#
# ITERATION No.: 2
#
# ...

# %% [markdown]
# ### **Ejemplo No.2**
# > Tres embalses estan conectados por tres tuberias cuyas caracteristicas para la tuberia 1 son: $L_1 = 150$ m, $\varepsilon = 1.2x10^{-4}$  m y $D_1 = 0.06$ m; para la tuberia 2 son: $L_2 = 80$  m, $\varepsilon_2 = 2.0x10^{-4}$  m y $D_2 = 0.04$  m; y para la tuberia 3 son: $L_3 = 100$ m, $\varepsilon_3 = 2.4x10^{-4}$ m y $D_3 = 0.08$ m. El nivel en los embalses es $z_1 = 100$ m, $z_2 = 40$ m y $z_3 = 20$ m. Las perdidas menores a lo largo de cada tuberia son despreciables.
#
#
# > - $\rho$ = 1000 kg/m$^3$
#
# > - $\nu$ = 1.02 X 10$^{-6}$ m$^2$/s
#
#
# ![alternatvie text](./figs/fw619.png)
#
# > *Solucion:*

# %% [markdown]
# > Siguiendo el procedimiento descrito, se tiene:

# %% [markdown]
# > La imformacion de entrada al programa es:

# %%
import json
with open('designTest_w619.json', 'r') as f:
    data = json.load(f)
data
# Out:
# {'PT': 1,
#  'US': 'IS',
#  'IM': 'nr',
#  'rho': 1000.0,
#  'mu': '',
#  'nu': 1.02e-06,
#  'RE1': {'z': 100},
#  'RE2': {'z': 40},
#  'RE3': {'z': 20},
#  'N1': {'z': 10.0, 'Q': 0.0},
#  'P1': {'S': 'RE1',
#   'E': 'N1',
#   'Q': '',
#   'Pu': {'P': '', 'h': '', 'ef': 1},
#   'D': 0.06,
#   'L': 150,
#   'ks': 0.00012,
#   'K': [0]},
#  'P2': {'S': 'N1',
#   'E': 'RE2',
#   'Q': '',
#   'Pu': {'P': '', 'h': '', 'ef': 1},
#   'D': 0.04,
#   'L': 80.0,
#   'ks': 0.0002,
#   'K': [0]},
#  'P3': {'S': 'N1',
#   'E': 'RE3',
#   'Q': '',
#   'Pu': {'P': '', 'h': '', 'ef': 1},
#   'D': 0.08,
#   'L': 100,
#   'ks': 0.00024,
#   'K': [0]}}

# %%
# %run main.py designTest_w619.json
# Out:
# Proving the design of a open pipe network
#
#
# ITERATION No.: 1
#
# ---> Resulst for Node: N1
#            Q         H             V            f
#           In Out    In Out        In Out       In Out
# P1  0.015342 NaN  90.0 NaN  5.426114 NaN  0.02399 NaN
# P2  0.000000 NaN   0.0 NaN  0.000000 NaN  0.00000 NaN
# P3  0.000000 NaN   0.0 NaN  0.000000 NaN  0.00000 NaN
#
# ITERATION No.: 2
#
# ---> Resulst for Node: N1
#      Q             H          V              f
#     In       Out  In    Out  In        Out  In       Out
# P1 NaN  0.015342 NaN   90.0 NaN   5.426114 NaN  0.023990
# P2 NaN  0.008697 NaN  150.0 NaN   6.920710 NaN  0.030723
# P3 NaN  0.050591 NaN  170.0 NaN  10.064681 NaN  0.026341
#
# ITERATION No.: 3
#
# ---> Resulst for Node: N1
#            Q               H             V             f
#           In Out          In Out        In Out        In Out
# P1  0.022594 NaN  193.742024 NaN  7.990911 NaN  0.023812 NaN
# ...

# %% [markdown]
# ## Diseno de tuberias
# ### **Ejemplo No.1**
# > El sistema de acueductos de la ciudad de San Juan tiene como una de sus partes componentes el sistema de tubos matrices que se muestra en la figura. Suponiendo que el datum se encuentra en la cota 1550 msnm, calcular el diametro requerido para cada uno de los tubos.
#
# > - $\rho$ = 999.1 kg/m$^3$
#
# > - $\nu$ = 1.14 X 10$^{-6}$ m$^2$/s
#
# ![alternatvie text](./figs/fjs67.jpeg)
#
# > *Solucion:*

# %% [markdown]
# > Siguiendo el procedimiento descrito, se tiene:

# %% [markdown]
# > La imformacion de entrada al programa es:

# %%
import json
with open('pipeDesign_js62.json', 'r') as f:
    data = json.load(f)
data
# Out:
# {'PT': 3,
#  'US': 'IS',
#  'IM': 'nr',
#  'rho': 999.1,
#  'mu': '',
#  'nu': 1.14e-06,
#  'RE1': {'z': 150},
#  'RE2': {'z': 90},
#  'RE3': {'z': 70},
#  'RE4': {'z': 55},
#  'RE5': {'z': 38},
#  'N1': {'z': 120.0, 'Q': 0.0},
#  'N2': {'z': 75.0, 'Q': 0.0},
#  'P1': {'S': 'RE1',
#   'E': 'N1',
#   'Q': 1.015,
#   'Pu': {'P': '', 'h': '', 'ef': 1},
#   'D': '',
#   'L': 1300,
#   'ks': 0.0003,
#   'K': [3.7]},
#  'P2': {'S': 'N1',
#   'E': 'RE2',
#   'Q': 0.31,
#   'Pu': {'P': '', 'h': '', 'ef': 1},
#   'D': '',
#   'L': 760,
#   'ks': 0.0003,
#   'K': [2.5]},
#  'P3': {'S': 'N1',
#   'E': 'RE3',
#   'Q': 0.12,
#   'Pu': {'P': '', 'h': '', 'ef': 1},
#   'D': '',
#   'L': 540,
#   'ks': 0.0003,
#   'K': [2.2]},
#  'P4': {'S': 'N1',
#   'E': 'N2',
#   'Q': 0.585,
#   'Pu': {'P': '', 'h': '', 'ef': 1},
#   'D': '',
#   'L': 2360,
#   'ks': 0.0005,
#   'K': [4.5]},
#  'P5': {'S': 'N2',
#   'E': 'RE4',
#   'Q': 0.33,
#   'Pu': {'P': '', 'h': '', 'ef': 1},
#   'D': '',
#   'L': 1150,
# ...

# %%
# %run main.py pipeDesign_js62.json
# Out:
# Design of a open pipe network
#
#
# ITERATION No.: 1
#
# ---> Resulst for Node: N1
#            Q               H               V                   f
#           In       Out    In   Out        In       Out        In       Out
# P1  1.123346       NaN  30.0   NaN  3.848876       NaN  0.016897       NaN  \
# P2       NaN  0.365609   NaN  30.0       NaN  3.681319       NaN  0.019152
# P3       NaN  0.130521   NaN  50.0       NaN  4.024799       NaN  0.021960
# P4       NaN  0.613229   NaN  45.0       NaN  3.025556       NaN  0.019793
#
#       D
#      In  Out
# P1   24  NaN
# P2  NaN   14
# P3  NaN    8
# P4  NaN   20
# ---> Resulst for Node: N2
#            Q                    H               V                   f
#           In       Out         In   Out        In       Out        In
# P4  0.616132       NaN  45.424703   NaN  3.039878       NaN  0.019792  \
# P5       NaN  0.340252        NaN  20.0       NaN  2.623032       NaN
# ...

# %% [markdown]
# ### **Ejemplo No.2**
# > La red abierta planteada en la figura muestra el sistema primario del sistema de abastecimiento de aguas de un municipio hipotetico. Los datos requeridos para el diseño son los siguientes:
#
# ![alternatvie text](./figs/fjs68.jpeg)
#
# > - Tubo 1-U: $L = 1350$ m; material, concreto; $\varepsilon = 0.0003$ m; $\sum K = 6.4$.
#
# > - Tubo U-2: $L = 2450$ m; material, concreto; $\varepsilon = 0.0003$ m; $\sum K = 7.1$.
#
# > - Tubo U-3: $L = 1710$ m; material, concreto; $\varepsilon = 0.0003$ m; $\sum K = 4.2$.
#
# > - Los caudales de salida en los nodos son: $Q_{D_2} = 360$ l/s y $Q_{D_3} = 190$ l/s
#
# > - Los cotas de los niveles en los embalses son: $Z_1 = 2640$ m, $Z_2 = 2635$ m y $Z_3 = 2610$ m.
#
# > - $\rho$ = 999.1 kg/m$^3$
#
# > - $\nu$ = 1.141 X 10$^{-6}$ m$^2$/s
#
# > Diseñar el sistema de la figura para las siguientes condiciones:
#
# > a. No colocar bomba.
#
# > b. La bomba de la tuberia U-2 produce una cabeza de 10 m para el caudal $Q_{D_2}$.
#
# > c. La bomba de la tuberia U-2 produce una cabeza de 50 m para el caudal $Q_{D_2}$.
#
#
# > *Solucion de a. (No colocar bomba):*

# %% [markdown]
# > Siguiendo el procedimiento descrito, se tiene:

# %% [markdown]
# > La imformacion de entrada al programa es:

# %%
import json
with open('pipeDesign_js63a.json', 'r') as f:
    data = json.load(f)
data
# Out:
# {'PT': 3,
#  'US': 'IS',
#  'IM': 'nr',
#  'rho': 999.1,
#  'mu': '',
#  'nu': 1.141e-06,
#  'RE1': {'z': 2640},
#  'RE2': {'z': 2635},
#  'RE3': {'z': 2610},
#  'N1': {'z': 2638.0, 'Q': 0.0},
#  'P1': {'S': 'RE1',
#   'E': 'N1',
#   'Q': 0.55,
#   'Pu': {'P': '', 'h': '', 'ef': 1},
#   'D': '',
#   'L': 1350,
#   'ks': 0.0003,
#   'K': [6.4]},
#  'P2': {'S': 'N1',
#   'E': 'RE2',
#   'Q': 0.36,
#   'Pu': {'P': '', 'h': '', 'ef': 1},
#   'D': '',
#   'L': 2450,
#   'ks': 0.0003,
#   'K': [7.1]},
#  'P3': {'S': 'N1',
#   'E': 'RE3',
#   'Q': 0.19,
#   'Pu': {'P': '', 'h': '', 'ef': 1},
#   'D': '',
#   'L': 1710,
#   'ks': 0.0003,
#   'K': [4.2]}}

# %%
# %run main.py pipeDesign_js63a.json
# Out:
# Design of a open pipe network
#
#
# ITERATION No.: 1
#
# ---> Resulst for Node: N1
#            Q              H               V                   f
#           In       Out   In   Out        In       Out        In       Out
# P1  0.751433       NaN  2.0   NaN  1.144269       NaN  0.015964       NaN  \
# P2       NaN  0.448464  NaN   3.0       NaN  0.983395       NaN  0.016722
# P3       NaN  0.236268  NaN  28.0       NaN  2.378988       NaN  0.019312
#
#       D
#      In  Out
# P1   36  NaN
# P2  NaN   30
# P3  NaN   14
#
# ITERATION No.: 2
#
# ---> Resulst for Node: N1
#            Q                   H                    V                   f
#           In       Out        In        Out        In       Out        In
# P1  0.702092       NaN  1.750019        NaN  1.069133       NaN  0.016011  \
# P2       NaN  0.467171       NaN   3.249981       NaN  1.024414       NaN
# P3       NaN  0.237332       NaN  28.249981       NaN  2.389702       NaN
#
#                D
# ...

# %% [markdown]
# > *Solucion de b. (La bomba de la tuberia U-2 produce una cabeza de 10 m para el caudal $Q_{D_2}$):*

# %% [markdown]
# > Siguiendo el procedimiento descrito, se tiene:

# %% [markdown]
# > La imformacion de entrada al programa es:

# %%
import json
with open('pipeDesign_js63b.json', 'r') as f:
    data = json.load(f)
data
# Out:
# {'PT': 3,
#  'US': 'IS',
#  'IM': 'nr',
#  'rho': 999.1,
#  'mu': '',
#  'nu': 1.141e-06,
#  'RE1': {'z': 2640},
#  'RE2': {'z': 2635},
#  'RE3': {'z': 2610},
#  'N1': {'z': 2630.0, 'Q': 0.0},
#  'P1': {'S': 'RE1',
#   'E': 'N1',
#   'Q': 0.55,
#   'Pu': {'P': '', 'h': '', 'ef': 1},
#   'D': '',
#   'L': 1350,
#   'ks': 0.0003,
#   'K': [6.4]},
#  'P2': {'S': 'N1',
#   'E': 'RE2',
#   'Q': 0.36,
#   'Pu': {'P': '', 'h': 10, 'ef': 1},
#   'D': '',
#   'L': 2450,
#   'ks': 0.0003,
#   'K': [7.1]},
#  'P3': {'S': 'N1',
#   'E': 'RE3',
#   'Q': 0.19,
#   'Pu': {'P': '', 'h': '', 'ef': 1},
#   'D': '',
#   'L': 1710,
#   'ks': 0.0003,
#   'K': [4.2]}}

# %%
# %run main.py pipeDesign_js63b.json
# Out:
# Design of a open pipe network
#
#
# ITERATION No.: 1
#
# ---> Resulst for Node: N1
#            Q               H               V                   f
#           In       Out    In   Out        In       Out        In       Out
# P1  0.614453       NaN  10.0   NaN  2.105277       NaN  0.017099       NaN  \
# P2       NaN  0.581841   NaN  -5.0       NaN  1.275865       NaN  0.016535
# P3       NaN  0.199279   NaN  20.0       NaN  2.006543       NaN  0.019394
#
#       D
#      In  Out
# P1   24  NaN
# P2  NaN   30
# P3  NaN   14
#
# ITERATION No.: 2
#
# ---> Resulst for Node: N1
#            Q                    H                    V                   f
#           In       Out         In        Out        In       Out        In
# P1  0.667344       NaN  11.775153        NaN  2.286492       NaN  0.017064  \
# P2       NaN  0.465323        NaN  -6.775153       NaN  1.020363       NaN
# P3       NaN  0.190113        NaN  18.224847       NaN  1.914247       NaN
#
#                 D
# ...

# %% [markdown]
# > *Solucion de c. (La bomba de la tuberia U-2 produce una cabeza de 50 m para el caudal $Q_{D_2}$):*

# %% [markdown]
# > Siguiendo el procedimiento descrito, se tiene:

# %% [markdown]
# > La imformacion de entrada al programa es:

# %%
import json
with open('pipeDesign_js63c.json', 'r') as f:
    data = json.load(f)
data
# Out:
# {'PT': 3,
#  'US': 'IS',
#  'IM': 'nr',
#  'rho': 999.1,
#  'mu': '',
#  'nu': 1.141e-06,
#  'RE1': {'z': 2640},
#  'RE2': {'z': 2635},
#  'RE3': {'z': 2610},
#  'N1': {'z': 2629.0, 'Q': 0.0},
#  'P1': {'S': 'RE1',
#   'E': 'N1',
#   'Q': 0.55,
#   'Pu': {'P': '', 'h': '', 'ef': 1},
#   'D': '',
#   'L': 1350,
#   'ks': 0.0003,
#   'K': [6.4]},
#  'P2': {'S': 'N1',
#   'E': 'RE2',
#   'Q': 0.36,
#   'Pu': {'P': '', 'h': 50, 'ef': 1},
#   'D': '',
#   'L': 2450,
#   'ks': 0.0003,
#   'K': [7.1]},
#  'P3': {'S': 'N1',
#   'E': 'RE3',
#   'Q': 0.19,
#   'Pu': {'P': '', 'h': '', 'ef': 1},
#   'D': '',
#   'L': 1710,
#   'ks': 0.0003,
#   'K': [4.2]}}

# %%
# %run main.py pipeDesign_js63c.json
# Out:
# Design of a open pipe network
#
#
# ITERATION No.: 1
#
# ---> Resulst for Node: N1
#            Q               H               V                   f
#           In       Out    In   Out        In       Out        In       Out
# P1  0.644776       NaN  11.0   NaN  2.209169       NaN  0.017079       NaN  \
# P2       NaN  0.472414   NaN  -6.0       NaN  2.877533       NaN  0.018131
# P3       NaN  0.194168   NaN  19.0       NaN  1.955078       NaN  0.019408
#
#       D
#      In  Out
# P1   24  NaN
# P2  NaN   18
# P3  NaN   14
#
# ITERATION No.: 2
#
# ---> Resulst for Node: N1
#            Q                    H                   V                   f
#           In       Out         In        Out       In       Out        In
# P1  0.653471       NaN  11.295532        NaN  2.23896       NaN  0.017073  \
# P2       NaN  0.470810        NaN  -6.295532      NaN  2.867765       NaN
# P3       NaN  0.192632        NaN  18.704468      NaN  1.939611       NaN
#
#                 D
# ...
