# %% [markdown]
# # Redes de tuberias cerradas
# ## Comprobación de diseño: Hardy-Cross con correccion de caudales
# ### **Ejemplo No.1**
# > La red mostrada en la figura tiene una valvula en la tuberia 2-3, la cual se encuentra parcialmente cerrada y cuyo coeficiente de perdidas es 10. Por otra lado, se sabe que la presion en el punto 1 es 100 mca y que el caudal de entrada a la red en este punto es de 200 l/s. Se requiere entonces analizar los caudales y las presiones en la red. Los diametros y las longitudes estan dadas en la figura. Despreciar las perdidas menores, exepto en la tuberia 2-3.
#
# > - $\rho =$ 999.1 kg/m$^3$
# > - $\nu =$ 1.14x10$^{-6}$ m$^2$/s
#
# ![alternatvie text](./figs/js72.jpeg)
#
# > *Solucion:*
#
# > Los caudales iniciales en las tuberias son los siguientes:
#
# > - Q$_{1-2}$ = 120 l/s
# > - Q$_{2-3}$ = 50 l/s
# > - Q$_{3-4}$ = 10 l/s
# > - Q$_{4-5}$ = -20 l/s
# > - Q$_{2-5}$ = 10 l/s
# > - Q$_{5-6}$ = -40 l/s
# > - Q$_{6-1}$ = -80 l/s

# %% [markdown]
# > Siguiendo el procedimiento descrito, se tiene:

# %% [markdown]
# > La imformacion de entrada al programa es:

# %%
import json
with open('designTest_js71q.json', 'r') as f:
    data = json.load(f)
data
# Out:
# {'PT': 1,
#  'ME': 'HCQ',
#  'US': 'IS',
#  'IM': 'nr',
#  'rho': 999.1,
#  'mu': '',
#  'nu': 1.14e-06,
#  'RE1': {'z': 100},
#  'N1': {'z': 100, 'Q': 0, 't': 'k'},
#  'N2': {'z': 0, 'Q': 0.06, 't': 'u'},
#  'N3': {'z': 0, 'Q': 0.04, 't': 'u'},
#  'N4': {'z': 0, 'Q': 0.03, 't': 'u'},
#  'N5': {'z': 0, 'Q': 0.03, 't': 'u'},
#  'N6': {'z': 0, 'Q': 0.04, 't': 'u'},
#  'P1': {'S': 'RE1',
#   'E': 'N1',
#   'Q': 0.2,
#   'Pu': {'P': '', 'h': '', 'ef': 1},
#   'D': '',
#   'L': '',
#   'ks': '',
#   'K': ''},
#  'P2': {'S': 'N1',
#   'E': 'N2',
#   'Q': 0.12,
#   'Pu': {'P': '', 'h': '', 'ef': 1},
#   'D': 0.254,
#   'L': 500,
#   'ks': 6e-05,
#   'K': [0]},
#  'P3': {'S': 'N2',
#   'E': 'N5',
#   'Q': 0.01,
#   'Pu': {'P': '', 'h': '', 'ef': 1},
#   'D': 0.1016,
#   'L': 200,
#   'ks': 6e-05,
#   'K': [0]},
#  'P4': {'S': 'N5',
#   'E': 'N6',
#   'Q': -0.04,
#   'Pu': {'P': '', 'h': '', 'ef': 1},
#   'D': 0.2032,
#   'L': 600,
#   'ks': 6e-05,
#   'K': [0]},
#  'P5': {'S': 'N6',
#   'E': 'N1',
#   'Q': -0.08,
#   'Pu': {'P': '', 'h': '', 'ef': 1},
#   'D': 0.254,
#   'L': 300,
#   'ks': 6e-05,
#   'K': [0]},
#  'P6': {'S': 'N2',
#   'E': 'N3',
#   'Q': 0.05,
#   'Pu': {'P': '', 'h': '', 'ef': 1},
#   'D': 0.1524,
#   'L': 400,
#   'ks': 6e-05,
#   'K': [10.0]},
#  'P7': {'S': 'N3',
#   'E': 'N4',
#   'Q': 0.01,
#   'Pu': {'P': '', 'h': '', 'ef': 1},
#   'D': 0.1016,
#   'L': 200,
#   'ks': 6e-05,
#   'K': [0]},
#  'P8': {'S': 'N4',
#   'E': 'N5',
#   'Q': -0.02,
#   'Pu': {'P': '', 'h': '', 'ef': 1},
#   'D': 0.1524,
#   'L': 400,
#   'ks': 6e-05,
#   'K': [0]},
#  'C1': ['N1', 'N2', 'N5', 'N6'],
#  'C2': ['N2', 'N3', 'N4', 'N5']}

# %%
# %run main.py designTest_js71q.json
# Out:
# {'C1': [1.0, 1.0, 1.0, 1.0], 'C2': [1.0, 1.0, 1.0, -1.0]}
# {'C1': ['P2', 'P3', 'P4', 'P5'], 'C2': ['P6', 'P7', 'P8', 'P3']}
# {'N1': ['P2', 'P5'], 'N2': ['P2', 'P3', 'P6'], 'N3': ['P6', 'P7'], 'N4': ['P7', 'P8'], 'N5': ['P3', 'P4', 'P8'], 'N6': ['P4', 'P5']}
# {'N1': ['P1', 'P2', 'P5'], 'N2': ['P2', 'P3', 'P6'], 'N3': ['P6', 'P7'], 'N4': ['P7', 'P8'], 'N5': ['P3', 'P4', 'P8'], 'N6': ['P4', 'P5']}
# {'N1': ['N2', 'N6'], 'N2': ['N1', 'N5', 'N3'], 'N3': ['N2', 'N4'], 'N4': ['N3', 'N5'], 'N5': ['N2', 'N6', 'N4'], 'N6': ['N5', 'N1']}
#
# Proving the design of a close pipe network: Hardy-Cross discharge correction method
#
#
# ITERATION No.: 1
#
# -> Circuit No.: 1
#        Q         f        hf   he     hf+he   (hf+he)/Q
# P2  0.12  0.015686  8.826960  0.0  8.826960   73.557998
# P3  0.01  0.020456  3.122573  0.0  3.122573  312.257251
# P4 -0.04  0.017500 -4.006985 -0.0 -4.006985  100.174637
# P5 -0.08  0.016257 -2.439409 -0.0 -2.439409   30.492609
# Delta Q = -0.005328 m³/s
#
# -> Circuit No.: 2
#            Q         f         hf        he      hf+he   (hf+he)/Q
# P6  0.050000  0.017312  17.400206  3.829317  21.229523  424.590468
# P7  0.010000  0.020456   3.122573  0.000000   3.122573  312.257251
# P8 -0.020000  0.018905  -3.040149 -0.000000  -3.040149  152.007425
# P3 -0.004672  0.022743  -0.757926 -0.000000  -0.757926  162.210428
# Delta Q = -0.009778 m³/s
#
#
# ITERATION No.: 2
#
# -> Circuit No.: 1
#            Q         f        hf   he     hf+he   (hf+he)/Q
# P2  0.114672  0.015743  8.089596  0.0  8.089596   70.545225
# P3  0.014450  0.019671  6.269760  0.0  6.269760  433.887730
# P4 -0.045328  0.017263 -5.075595 -0.0 -5.075595  111.976014
# P5 -0.085328  0.016156 -2.757879 -0.0 -2.757879   32.321102
# Delta Q = -0.005030 m³/s
#
# -> Circuit No.: 2
#            Q         f         hf        he      hf+he   (hf+he)/Q
# P6  0.040222  0.017608  11.452216  2.478078  13.930295  346.332678
# P7  0.000222  0.046873   0.003536  0.000000   0.003536   15.904870
# P8 -0.029778  0.018096  -6.450823 -0.000000  -6.450823  216.632617
# P3 -0.009420  0.020602  -2.790836 -0.000000  -2.790836  296.252849
# Delta Q = -0.002681 m³/s
#
#
# ITERATION No.: 3
#
# -> Circuit No.: 1
#            Q         f        hf   he     hf+he   (hf+he)/Q
# P2  0.109643  0.015800  7.422523  0.0  7.422523   67.697345
# P3  0.012101  0.020026  4.476577  0.0  4.476577  369.924756
# P4 -0.050357  0.017076 -6.196914 -0.0 -6.196914  123.059010
# P5 -0.090357  0.016069 -3.076067 -0.0 -3.076067   34.043392
# Delta Q = -0.002208 m³/s
#
# -> Circuit No.: 2
#            Q         f         hf        he      hf+he   (hf+he)/Q
# P6  0.037541  0.017711  10.035066  2.158753  12.193819  324.809657
# P7 -0.002459  0.025515  -0.235424 -0.000000  -0.235424   95.756503
# P8 -0.032459  0.017946  -7.601048 -0.000000  -7.601048  234.176914
# P3 -0.009893  0.020482  -3.060241 -0.000000  -3.060241  309.319172
# Delta Q = -0.000673 m³/s
#
#
# ITERATION No.: 4
#
# -> Circuit No.: 1
#            Q         f        hf   he     hf+he   (hf+he)/Q
# P2  0
#
# -> Circuit No.: 1
#            Q         f        hf   he     hf+he   (hf+he)/Q
# P2  0.106645  0.015837  7.038350  0.0  7.038350   65.998089
# P3  0.010051  0.020444  3.152584  0.0  3.152584  313.661149
# P4 -0.053355  0.016979 -6.917120 -0.0 -6.917120  129.642741
# P5 -0.093355  0.016021 -3.273811 -0.0 -3.273811   35.068310
# Delta Q = -0.000000 m³/s
#
# -> Circuit No.: 2
#            Q         f        hf        he      hf+he   (hf+he)/Q
# P6  0.036594  0.017751  9.556172  2.051149  11.607320  317.193353
# P7 -0.003406  0.024001 -0.425045 -0.000000  -0.425045  124.786908
# P8 -0.033406  0.017897 -8.029691 -0.000000  -8.029691  240.365524
# P3 -0.010051  0.020444 -3.152582 -0.000000  -3.152582  313.661076
# Delta Q = -0.000000 m³/s
#
#
# ITERATION No.: 14
#
# -> Circuit No.: 1
#            Q         f        hf   he     hf+he   (hf+he)/Q
# P2  0.106645  0.015837  7.038350  0.0  7.038350   65.998088
# P3  0.010051  0.020444  3.152583  0.0  3.152583  313.661103
# P4 -0.053355  0.016979 -6.917121 -0.0 -6.917121  129.642746
# P5 -0.093355  0.016021 -3.273811 -0.0 -3.273811   35.068311
# Delta Q = -0.000000 m³/s
#
# -> Circuit No.: 2
#            Q         f        hf        he      hf+he   (hf+he)/Q
# P6  0.036594  0.017751  9.556171  2.051149  11.607320  317.193345
# P7 -0.003406  0.024000 -0.425045 -0.000000  -0.425045  124.786938
# P8 -0.033406  0.017897 -8.029691 -0.000000  -8.029691  240.365531
# P3 -0.010051  0.020444 -3.152582 -0.000000  -3.152582  313.661085
# Delta Q = -0.000000 m³/s
#
#
# ITERATION No.: 15
#
# -> Circuit No.: 1
#            Q         f        hf   he     hf+he   (hf+he)/Q
# P2  0.106645  0.015837  7.038350  0.0  7.038350   65.998088
# P3  0.010051  0.020444  3.152583  0.0  3.152583  313.661092
# P4 -0.053355  0.016979 -6.917121 -0.0 -6.917121  129.642748
# P5 -0.093355  0.016021 -3.273811 -0.0 -3.273811   35.068312
# Delta Q = -0.000000 m³/s
#
# -> Circuit No.: 2
#            Q         f        hf        he      hf+he   (hf+he)/Q
# P6  0.036594  0.017751  9.556171  2.051149  11.607320  317.193343
# P7 -0.003406  0.024000 -0.425045 -0.000000  -0.425045  124.786945
# P8 -0.033406  0.017897 -8.029692 -0.000000  -8.029692  240.365532
# P3 -0.010051  0.020444 -3.152582 -0.000000  -3.152582  313.661087
# Delta Q = -0.000000 m³/s
#
# Summmary of discharges
# Discharge in Pipe No. 1 (P1) = 200.00000 l/s
# Discharge in Pipe No. 2 (P2) = 106.64475 l/s
# Discharge in Pipe No. 3 (P3) = 10.05092 l/s
# Discharge in Pipe No. 4 (P4) = -53.35525 l/s
# Discharge in Pipe No. 5 (P5) = -93.35525 l/s
# Discharge in Pipe No. 6 (P6) = 36.59383 l/s
# Discharge in Pipe No. 7 (P7) = -3.40617 l/s
# Discharge in Pipe No. 8 (P8) = -33.40617 l/s
#
# Summmary of node heads
# Head in Node No. 1 (N1) = 100.00000 (m)
# Head in Node No. 2 (N2) = 92.96165 (m)
# Head in Node No. 3 (N3) = 81.35433 (m)
# Head in Node No. 4 (N4) = 81.77938 (m)
# Head in Node No. 5 (N5) = 89.80907 (m)
# Head in Node No. 6 (N6) = 96.72619 (m)

# %% [markdown]
# ### **Ejemplo No.2**
# > Determinar los caudales que fluye por la red de distribucion definida en la figura. La red se encuentra en un plano horizontal y en el nodo H existe un aporte a la red de 300 l/s, mientras que en los nodos D, E y F existen demandas de caudal de 60, 90 y 150 l/s, respectivamente.
#
# > - $\rho$ = 1000 kg/m$^3$
#
# > - $\nu$ = 1.02 X 10$^{-6}$ m$^2$/s
#
# ![alternatvie text](./figs/cd619.jpeg)
#
# > Las caracteristicas de las tuberias se encuentran definidas en la siguiente tabla.
#
# ![alternatvie text](./figs/cd610.jpeg)
#
# > Los caudales iniciales y sus direcciones se encuentran definidos en la siguiente figura.
#
# ![alternatvie text](./figs/cd620.jpeg)
#
# > *Solucion:*

# %% [markdown]
# > Siguiendo el procedimiento descrito, se tiene:

# %% [markdown]
# > La imformacion de entrada al programa es:

# %%
import json
with open('designTest_cd68q.json', 'r') as f:
    data = json.load(f)
data
# Out:
# {'PT': 1,
#  'ME': 'HCQ',
#  'US': 'IS',
#  'IM': 'nr',
#  'rho': 999.1,
#  'mu': '',
#  'nu': 1.141e-06,
#  'RE1': {'z': 100.0},
#  'N1': {'z': 100.0, 'Q': 0, 't': 'k'},
#  'N2': {'z': 0, 'Q': 0, 't': 'u'},
#  'N3': {'z': 0, 'Q': 0, 't': 'u'},
#  'N4': {'z': 0, 'Q': 0.09, 't': 'u'},
#  'N5': {'z': 0, 'Q': 0, 't': 'u'},
#  'N6': {'z': 0, 'Q': 0, 't': 'u'},
#  'N7': {'z': 0, 'Q': 0.15, 't': 'u'},
#  'N8': {'z': 0, 'Q': 0.06, 't': 'u'},
#  'N9': {'z': 0, 'Q': 0, 't': 'u'},
#  'N10': {'z': 0, 'Q': 0, 't': 'u'},
#  'P1': {'S': 'RE1',
#   'E': 'N1',
#   'Q': 0.3,
#   'Pu': {'P': '', 'h': '', 'ef': 1},
#   'D': '',
#   'L': '',
#   'ks': '',
#   'K': ''},
#  'P2': {'S': 'N1',
#   'E': 'N2',
#   'Q': 0.107,
#   'Pu': {'P': '', 'h': '', 'ef': 1},
#   'D': 0.6,
#   'L': 500,
#   'ks': 0.0009,
#   'K': [0]},
#  'P3': {'S': 'N2',
#   'E': 'N3',
#   'Q': 0.107,
#   'Pu': {'P': '', 'h': '', 'ef': 1},
#   'D': 0.45,
#   'L': 300,
#   'ks': 0.0009,
#   'K': [0]},
#  'P4': {'S': 'N3',
#   'E': 'N4',
#   'Q': 0.03,
#   'Pu': {'P': '', 'h': '', 'ef': 1},
#   'D': 0.4,
#   'L': 250,
#   'ks': 0.00055,
#   'K': [0]},
#  'P5': {'S': 'N4',
#   'E': 'N5',
#   'Q': -0.104,
#   'Pu': {'P': '', 'h': '', 'ef': 1},
#   'D': 0.45,
#   'L': 250,
#   'ks': 0.0009,
#   'K': [0]},
#  'P6': {'S': 'N5',
#   'E': 'N1',
#   'Q': -0.193,
#   'Pu': {'P': '', 'h': '', 'ef': 1},
#   'D': 0.6,
#   'L': 300,
#   'ks': 0.0009,
#   'K': [0]},
#  'P7': {'S': 'N3',
#   'E': 'N6',
#   'Q': 0.077,
#   'Pu': {'P': '', 'h': '', 'ef': 1},
#   'D': 0.45,
#   'L': 150,
#   'ks': 0.0009,
#   'K': [0]},
#  'P8': {'S': 'N6',
#   'E': 'N7',
#   'Q': 0.061,
#   'Pu': {'P': '', 'h': '', 'ef': 1},
#   'D': 0.4,
#   'L': 250,
#   'ks': 0.00055,
#   'K': [0]},
#  'P9': {'S': 'N7',
#   'E': 'N4',
#   'Q': -0.044,
#   'Pu': {'P': '', 'h': '', 'ef': 1},
#   'D': 0.3,
#   'L': 150,
#   'ks': 0.00055,
#   'K': [0]},
#  'P10': {'S': 'N6',
#   'E': 'N8',
#   'Q': 0.016,
#   'Pu': {'P': '', 'h': '', 'ef': 1},
#   'D': 0.45,
#   'L': 150,
#   'ks': 0.0009,
#   'K': [0]},
#  'P11': {'S': 'N8',
#   'E': 'N9',
#   'Q': -0.044,
#   'Pu': {'P': '', 'h': '', 'ef': 1},
#   'D': 0.4,
#   'L': 250,
#   'ks': 0.00055,
#   'K': [0]},
#  'P12': {'S': 'N9',
#   'E': 'N7',
#   'Q': 0.045,
#   'Pu': {'P': '', 'h': '', 'ef': 1},
#   'D': 0.3,
#   'L': 150,
#   'ks': 0.00055,
#   'K': [0]},
#  'P13': {'S': 'N9',
#   'E': 'N10',
#   'Q': -0.089,
#   'Pu': {'P': '', 'h': '', 'ef': 1},
#   'D': 0.45,
#   'L': 250,
#   'ks': 0.0009,
#   'K': [0]},
#  'P14': {'S': 'N10',
#   'E': 'N5',
#   'Q': -0.089,
#   'Pu': {'P': '', 'h': '', 'ef': 1},
#   'D': 0.6,
#   'L': 300,
#   'ks': 0.0009,
#   'K': [0]},
#  'C1': ['N1', 'N2', 'N3', 'N4', 'N5'],
#  'C2': ['N3', 'N6', 'N7', 'N4'],
#  'C3': ['N6', 'N8', 'N9', 'N7'],
#  'C4': ['N4', 'N7', 'N9', 'N10', 'N5']}

# %%
# %run main.py designTest_cd68q.json
# Out:
# {'C1': ['P2', 'P3', 'P4', 'P5', 'P6'], 'C2': ['P7', 'P8', 'P9', 'P4'], 'C3': ['P10', 'P11', 'P12', 'P8'], 'C4': ['P9', 'P12', 'P13', 'P14', 'P5']}
# {'N1': ['P1', 'P2', 'P6'], 'N2': ['P2', 'P3'], 'N3': ['P3', 'P4', 'P7'], 'N4': ['P4', 'P5', 'P9'], 'N5': ['P5', 'P6', 'P14'], 'N6': ['P7', 'P8', 'P10'], 'N7': ['P8', 'P9', 'P12'], 'N8': ['P10', 'P11'], 'N9': ['P11', 'P12', 'P13'], 'N10': ['P13', 'P14']}
# {'N1': ['N2', 'N5'], 'N2': ['N1', 'N3'], 'N3': ['N2', 'N4', 'N6'], 'N4': ['N3', 'N5', 'N7'], 'N5': ['N4', 'N1', 'N10'], 'N6': ['N3', 'N7', 'N8'], 'N7': ['N6', 'N4', 'N9'], 'N8': ['N6', 'N9'], 'N9': ['N8', 'N7', 'N10'], 'N10': ['N9', 'N5']}
#
# Proving the design of a close pipe network: Hardy-Cross discharge correction method
#
# here N1 [0.0193, 0.36669999999999997]
# *** P1 0.3
# *** P2 0.107
# *** P6 -0.193
# here N2 0.0
# *** P2 0.107
# *** P3 0.107
# here N3 0.0
# *** P3 0.107
# *** P4 0.03
# *** P7 0.077
# here N4 6.938893903907228e-18
# *** P4 0.03
# *** P5 -0.104
# *** P9 -0.044
# here N5 -0.386
# *** P5 -0.104
# *** P6 -0.193
# *** P14 -0.089
# here N6 0.0
# *** P7 0.077
# *** P8 0.061
# *** P10 0.016
# here N7 0.0
# *** P8 0.061
# *** P9 -0.044
# *** P12 0.045
# here N8 0.0
# *** P10 0.016
# *** P11 -0.044
# here N9 0.0
# *** P11 -0.044
# *** P12 0.045
# *** P13 -0.089
# --------> 0.772
# here N1 [0.03, 0.27]
# *** P1 0.3
# *** P2 0.03
# *** P6 0.27
# here N2 0.03
# *** P2 0.03
# *** P3 0.03
# here N3 0.015
# *** P3 0.03
# *** P4 0.015
# *** P7 0.015
# here N4 -0.0375
# *** P4 0.015
# *** P5 -0.0375
# *** P9 0.0375
# here N5 0.2325
# *** P5 -0.0375
# *** P6 0.27
# *** P14 -0.2325
# here N6 0.0075
# *** P7 0.015
# *** P8 0.0075
# *** P10 0.0075
# here N7 -0.18
# *** P8 0.0075
# *** P9 0.0375
# *** P12 0.18
# here N8 -0.0525
# *** P10 0.0075
# *** P11 -0.0525
# here N9 -0.23249999999999998
# *** P11 -0.0525
# *** P12 0.18
# *** P13 -0.23249999999999998
# --------> 2.7755575615628914e-17
# P1 0.3
# P2 0.03
# P3 0.03
# P4 0.015
# P5 -0.0375
# P6 0.27
# P7 0.015
# P8 0.0075
# P9 0.0375
# P10 0.0075
# P11 -0.0525
# P12 0.18
# P13 -0.23249999999999998
# P14 -0.2325
#
# ITERATION No.: 1
#
# -> Circuit No.: 1
#          Q         f        hf   he     hf+he  (hf+he)/Q
# P2  0.0300  0.025016  0.011962  0.0  0.011962   0.398728
# P3  0.0300  0.025614  0.030967  0.0  0.030967   1.032230
# P4  0.0150  0.025570  0.011606  0.0  0.011606   0.773716
# P5 -0.0375  0.025220 -0.039702 -0.0 -0.039702   1.058719
# P6 -0.2700  0.022176 -0.515353 -0.0 -0.515353   1.908716
# Delta Q = 0.048387 m³/s
#
# -> Circuit No.: 2
#            Q         f        hf   he     hf+he  (hf+he)/Q
# P7  0.015000  0.027357  0.004134  0.0  0.004134   0.275624
# P8  0.007500  0.028431  0.003226  0.0  0.003226   0.430144
# P9  0.037500  0.024204  0.173604  0.0  0.173604   4.629428
# P4 -0.063387  0.022526 -0.182572 -0.0 -0.182572   2.880292
# Delta Q = 0.000098 m³/s
#
# -> Circuit No.: 3
#             Q         f        hf   he     hf+he  (hf+he)/Q
# P10  0.007500  0.030139  0.001139  0.0  0.001139   0.151822
# P11 -0.052500  0.022762 -0.126560 -0.0 -0.126560   2.410669
# P12  0.180000  0.023183  3.830996  0.0  3.830996  21.283313
# P8  -0.007598  0.028367 -0.003303 -0.0 -0.003303   0.434768
# Delta Q = -0.076239 m³/s
#
# -> Circuit No.: 4
#             Q         f        hf   he     hf+he  (hf+he)/Q
# P9  -0.037598  0.024201 -0.174488 -0.0 -0.174488   4.640905
# P12 -0.103761  0.023391 -1.284480 -0.0 -1.284480  12.379262
# P13 -0.232500  0.023741 -1.436625 -0.0 -1.436625   6.179032
# P14 -0.232500  0.022246 -0.383342 -0.0 -0.383342   1.648782
# P5  -0.010887  0.028494 -0.003780 -0.0 -0.003780   0.347253
# Delta Q = 0.065146 m³/s
#
#
# ITERATION No.: 2
#
# -> Circuit No.: 1
#            Q         f        hf   he     hf+he  (hf+he)/Q
# P2  0.078387  0.023164  0.075618  0.0  0.075618   0.964685
# P3  0.078387  0.024334  0.200848  0.0  0.200848   2.562281
# P4  0.063289  0.022527  0.182023  0.0  0.182023   2.876075
# P5 -0.054259  0.024707 -0.081426 -0.0 -0.081426   1.500693
# P6 -0.221613  0.022271 -0.348666 -0.0 -0.348666   1.573309
# Delta Q = -0.001498 m³/s
#
# -> Circuit No.: 2
#            Q         f        hf   he     hf+he  (hf+he)/Q
# P7  0.015098  0.027337  0.004185  0.0  0.004185   0.277213
# P8  0.083837  0.022237  0.315285  0.0  0.315285   3.760679
# P9 -0.027548  0.024629 -0.095327 -0.0 -0.095327   3.460443
# P4 -0.061790  0.022556 -0.173724 -0.0 -0.173724   2.811496
# Delta Q = -0.002445 m³/s
#
# -> Circuit No.: 3
#             Q         f        hf   he     hf+he  (hf+he)/Q
# P10 -0.068739  0.024453 -0.077607 -0.0 -0.077607   1.129000
# P11 -0.128739  0.021909 -0.732515 -0.0 -0.732515   5.689904
# P12  0.038615  0.024169  0.183816  0.0  0.183816   4.760203
# P8  -0.081392  0.022264 -0.297529 -0.0 -0.297529   3.655500
# Delta Q = 0.030320 m³/s
#
# -> Circuit No.: 4
#             Q         f        hf   he     hf+he  (hf+he)/Q
# P9   0
# Delta Q = 0.000000 m³/s
#
# -> Circuit No.: 2
#            Q         f        hf   he     hf+he  (hf+he)/Q
# P7  0.078236  0.024335  0.100045  0.0  0.100045   1.278763
# P8  0.061305  0.022565  0.171074  0.0  0.171074   2.790555
# P9 -0.043302  0.024041 -0.229917 -0.0 -0.229917   5.309610
# P4 -0.029318  0.023762 -0.041202 -0.0 -0.041202   1.405354
# Delta Q = 0.000000 m³/s
#
# -> Circuit No.: 3
#             Q         f        hf   he     hf+he  (hf+he)/Q
# P10  0.016931  0.026987  0.005196  0.0  0.005196   0.306898
# P11 -0.043069  0.023053 -0.086262 -0.0 -0.086262   2.002881
# P12  0.045393  0.023991  0.252140  0.0  0.252140   5.554579
# P8  -0.061305  0.022565 -0.171074 -0.0 -0.171074   2.790556
# Delta Q = 0.000000 m³/s
#
# -> Circuit No.: 4
#             Q         f        hf   he     hf+he  (hf+he)/Q
# P9   0.043302  0.024041  0.229917  0.0  0.229917   5.309606
# P12 -0.045393  0.023991 -0.252140 -0.0 -0.252140   5.554582
# P13 -0.088462  0.024235 -0.212303 -0.0 -0.212303   2.399927
# P14 -0.088462  0.023014 -0.057412 -0.0 -0.057412   0.648996
# P5   0.103984  0.024119  0.291936  0.0  0.291936   2.807512
# Delta Q = 0.000000 m³/s
#
#
# ITERATION No.: 33
#
# -> Circuit No.: 1
#            Q         f        hf   he     hf+he  (hf+he)/Q
# P2  0.107554  0.022803  0.140144  0.0  0.140144   1.303010
# P3  0.107554  0.024097  0.374446  0.0  0.374446   3.481474
# P4  0.029318  0.023762  0.041202  0.0  0.041202   1.405353
# P5 -0.103984  0.024119 -0.291936 -0.0 -0.291936   2.807512
# P6 -0.192446  0.022349 -0.263856 -0.0 -0.263856   1.371064
# Delta Q = 0.000000 m³/s
#
# -> Circuit No.: 2
#            Q         f        hf   he     hf+he  (hf+he)/Q
# P7  0.078236  0.024335  0.100045  0.0  0.100045   1.278764
# P8  0.061305  0.022565  0.171074  0.0  0.171074   2.790555
# P9 -0.043302  0.024041 -0.229917 -0.0 -0.229917   5.309609
# P4 -0.029318  0.023762 -0.041202 -0.0 -0.041202   1.405353
# Delta Q = 0.000000 m³/s
#
# -> Circuit No.: 3
#             Q         f        hf   he     hf+he  (hf+he)/Q
# P10  0.016931  0.026987  0.005196  0.0  0.005196   0.306899
# P11 -0.043069  0.023053 -0.086262 -0.0 -0.086262   2.002879
# P12  0.045393  0.023991  0.252140  0.0  0.252140   5.554579
# P8  -0.061305  0.022565 -0.171074 -0.0 -0.171074   2.790556
# Delta Q = 0.000000 m³/s
#
# -> Circuit No.: 4
#             Q         f        hf   he     hf+he  (hf+he)/Q
# P9   0.043302  0.024041  0.229917  0.0  0.229917   5.309607
# P12 -0.045393  0.023991 -0.252140 -0.0 -0.252140   5.554581
# P13 -0.088462  0.024235 -0.212303 -0.0 -0.212303   2.399927
# P14 -0.088462  0.023014 -0.057412 -0.0 -0.057412   0.648996
# P5   0.103984  0.024119  0.291936  0.0  0.291936   2.807512
# Delta Q = 0.000000 m³/s
#
#
# ITERATION No.: 34
#
# -> Circuit No.: 1
#            Q         f        hf   he     hf+he  (hf+he)/Q
# P2  0.107554  0.022803  0.140144  0.0  0.140144   1.303010
# P3  0.107554  0.024097  0.374446  0.0  0.374446   3.481474
# P4  0.029318  0.023762  0.041202  0.0  0.041202   1.405352
# P5 -0.103984  0.024119 -0.291936 -0.0 -0.291936   2.807512
# P6 -0.192446  0.022349 -0.263856 -0.0 -0.263856   1.371064
# Delta Q = 0.000000 m³/s
#
# -> Circuit No.: 2
#            Q         f        hf   he     hf+he  (hf+he)/Q
# P7  0.078236  0.024335  0.100045  0.0  0.100045   1.278764
# P8  0.061305  0.022565  0.171074  0.0  0.171074   2.790555
# P9 -0.043302  0.024041 -0.229917 -0.0 -0.229917   5.309608
# P4 -0.029318  0.023762 -0.041202 -0.0 -0.041202   1.405352
# Delta Q = 0.000000 m³/s
#
# -> Circuit No.: 3
#             Q         f        hf   he     hf+he  (hf+he)/Q
# P10  0.016931  0.026987  0.005196  0.0  0.005196   0.306899
# P11 -0.043069  0.023053 -0.086262 -0.0 -0.086262   2.002879
# P12  0.045393  0.023991  0.252140  0.0  0.252140   5.554580
# P8  -0.061305  0.022565 -0.171074 -0.0 -0.171074   2.790556
# Delta Q = 0.000000 m³/s
#
# -> Circuit No.: 4
#             Q         f        hf   he     hf+he  (hf+he)/Q
# P9   0.043302  0.024041  0.229917  0.0  0.229917   5.309607
# P12 -0.045393  0.023991 -0.252140 -0.0 -0.252140   5.554581
# P13 -0.088462  0.024235 -0.212302 -0.0 -0.212302   2.399926
# P14 -0.088462  0.023014 -0.057412 -0.0 -0.057412   0.648996
# P5   0.103984  0.024119  0.291936  0.0  0.291936   2.807512
# Delta Q = 0.000000 m³/s
#
# Summmary of discharges
# Discharge in Pipe No. 1 (P1) = 300.00000 l/s
# Discharge in Pipe No. 2 (P2) = 107.55390 l/s
# Discharge in Pipe No. 3 (P3) = 107.55390 l/s
# Discharge in Pipe No. 4 (P4) = 29.31810 l/s
# Discharge in Pipe No. 5 (P5) = -103.98403 l/s
# Discharge in Pipe No. 6 (P6) = 192.44610 l/s
# Discharge in Pipe No. 7 (P7) = 78.23581 l/s
# Discharge in Pipe No. 8 (P8) = 61.30473 l/s
# Discharge in Pipe No. 9 (P9) = -43.30213 l/s
# Discharge in Pipe No. 10 (P10) = 16.93108 l/s
# Discharge in Pipe No. 11 (P11) = -43.06892 l/s
# Discharge in Pipe No. 12 (P12) = 45.39314 l/s
# Discharge in Pipe No. 13 (P13) = -88.46207 l/s
# Discharge in Pipe No. 14 (P14) = -88.46207 l/s
#
# Summmary of node heads
# Head in Node No. 1 (N1) = 100.00000 (m)
# Head in Node No. 2 (N2) = 99.85986 (m)
# Head in Node No. 3 (N3) = 99.48541 (m)
# Head in Node No. 4 (N4) = 99.44421 (m)
# Head in Node No. 5 (N5) = 99.73614 (m)
# Head in Node No. 6 (N6) = 99.38536 (m)
# Head in Node No. 7 (N7) = 99.67413 (m)
# Head in Node No. 8 (N8) = 99.38017 (m)
# Head in Node No. 9 (N9) = 99.42199 (m)
# Head in Node No. 10 (N10) = 99.79356 (m)

# %% [markdown]
# ## Comprobación de diseño: Hardy-Cross con correccion de cabezas
# ### **Ejemplo No.1**
# > La red mostrada en la figura tiene una valvula en la tuberia 2-3, la cual se encuentra parcialmente cerrada y cuyo coeficiente de perdidas es 10. Por otra lado, se sabe que la presion en el punto 1 es 100 mca y que el caudal de entrada a la red en este punto es de 200 l/s. Se requiere entonces analizar los caudales y las presiones en la red. Los diametros y las longitudes estan dadas en la figura. Despreciar las perdidas menores, exepto en la tuberia 2-3.
#
# > - $\rho =$ 999.1 kg/m$^3$
# > - $\nu =$ 1.14x10$^{-6}$ m$^2$/s
#
# ![alternatvie text](./figs/js72.jpeg)
#
# > *Solucion:*
#
# > Las presiones iniciales en los nodos son las siguientes:
#
# > - P$_{1}$ = 100 mca
# > - P$_{2}$ = 92 mca
# > - P$_{3}$ = 80 mca
# > - P$_{4}$ = 75 mca
# > - P$_{5}$ = 90 mca
# > - P$_{6}$ = 95 mca
